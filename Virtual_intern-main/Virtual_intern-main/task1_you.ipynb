# %%
##load the dataset
import pandas as pd 
transactionData=pd.read_csv('QVI_purchase_behaviour.csv')
customerData=pd.read_excel("QVI_transaction_data.xlsx")

# %%
## Exploratory data analysis

transactionData.head(10)
# Out:
#    LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0            1000   YOUNG SINGLES/COUPLES          Premium
# 1            1002   YOUNG SINGLES/COUPLES       Mainstream
# 2            1003          YOUNG FAMILIES           Budget
# 3            1004   OLDER SINGLES/COUPLES       Mainstream
# 4            1005  MIDAGE SINGLES/COUPLES       Mainstream
# 5            1007   YOUNG SINGLES/COUPLES           Budget
# 6            1009            NEW FAMILIES          Premium
# 7            1010   YOUNG SINGLES/COUPLES       Mainstream
# 8            1011   OLDER SINGLES/COUPLES       Mainstream
# 9            1012          OLDER FAMILIES       Mainstream

# %%
customerData["DATE"]=pd.to_datetime(customerData["DATE"], origin = "1899-12-30",unit="D")

# %%
customerData.head(10)
# Out:
#         DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0 2018-10-17          1            1000       1         5
# 1 2019-05-14          1            1307     348        66
# 2 2019-05-20          1            1343     383        61
# 3 2018-08-17          2            2373     974        69
# 4 2018-08-18          2            2426    1038       108
# 5 2019-05-19          4            4074    2982        57
# 6 2019-05-16          4            4149    3333        16
# 7 2019-05-16          4            4196    3539        24
# 8 2018-08-20          5            5026    4525        42
# 9 2018-08-18          7            7150    6900        52
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# ...

# %%
transactionData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72637 entries, 0 to 72636
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LYLTY_CARD_NBR    72637 non-null  int64
#  1   LIFESTAGE         72637 non-null  object
#  2   PREMIUM_CUSTOMER  72637 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
transactionData.shape
# Out:
# (72637, 3)

# %%
transactionData.describe(include=['object', 'bool'])
# Out:
#        LIFESTAGE PREMIUM_CUSTOMER
# count      72637            72637
# unique         7                3
# top     RETIREES       Mainstream
# freq       14805            29245

# %%
transactionData['PREMIUM_CUSTOMER'].value_counts()
# Out:
# Mainstream    29245
# Budget        24470
# Premium       18922
# Name: PREMIUM_CUSTOMER, dtype: int64

# %%
transactionData['LIFESTAGE'].value_counts()
# Out:
# RETIREES                  14805
# OLDER SINGLES/COUPLES     14609
# YOUNG SINGLES/COUPLES     14441
# OLDER FAMILIES             9780
# YOUNG FAMILIES             9178
# MIDAGE SINGLES/COUPLES     7275
# NEW FAMILIES               2549
# Name: LIFESTAGE, dtype: int64

# %%
customerData.shape
# Out:
# (264836, 8)

# %%
customerData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DATE            264836 non-null  datetime64[ns]
#  1   STORE_NBR       264836 non-null  int64
#  2   LYLTY_CARD_NBR  264836 non-null  int64
#  3   TXN_ID          264836 non-null  int64
#  4   PROD_NBR        264836 non-null  int64
#  5   PROD_NAME       264836 non-null  object
#  6   PROD_QTY        264836 non-null  int64
#  7   TOT_SALES       264836 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(1)
# memory usage: 16.2+ MB

# %%
customerData.describe()
# Out:
#           STORE_NBR  LYLTY_CARD_NBR        TXN_ID       PROD_NBR  \
# count  264836.00000    2.648360e+05  2.648360e+05  264836.000000
# mean      135.08011    1.355495e+05  1.351583e+05      56.583157
# std        76.78418    8.057998e+04  7.813303e+04      32.826638
# min         1.00000    1.000000e+03  1.000000e+00       1.000000
# 25%        70.00000    7.002100e+04  6.760150e+04      28.000000
# 50%       130.00000    1.303575e+05  1.351375e+05      56.000000
# 75%       203.00000    2.030942e+05  2.027012e+05      85.000000
# max       272.00000    2.373711e+06  2.415841e+06     114.000000
#
#             PROD_QTY      TOT_SALES
# count  264836.000000  264836.000000
# mean        1.907309       7.304200
# std         0.643654       3.083226
# min         1.000000       1.500000
# 25%         2.000000       5.400000
# 50%         2.000000       7.400000
# 75%         2.000000       9.200000
# max       200.000000     650.000000

# %%
customerData.describe(include=['object', 'bool'])
# Out:
#                                      PROD_NAME
# count                                   264836
# unique                                     114
# top     Kettle Mozzarella   Basil & Pesto 175g
# freq                                      3304

# %%
customerData['PROD_NAME'].value_counts()
# Out:
# Kettle Mozzarella   Basil & Pesto 175g      3304
# Kettle Tortilla ChpsHny&Jlpno Chili 150g    3296
# Cobs Popd Swt/Chlli &Sr/Cream Chips 110g    3269
# Tyrrells Crisps     Ched & Chives 165g      3268
# Cobs Popd Sea Salt  Chips 110g              3265
#                                             ...
# RRD Pc Sea Salt     165g                    1431
# Woolworths Medium   Salsa 300g              1430
# NCC Sour Cream &    Garden Chives 175g      1419
# French Fries Potato Chips 175g              1418
# WW Crinkle Cut      Original 175g           1410
# Name: PROD_NAME, Length: 114, dtype: int64

# %%
customerData.sort_values(by='PROD_QTY',
        ascending= False)
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 69762  2018-08-19        226          226000  226201         4
# 69763  2019-05-20        226          226000  226210         4
# 217237 2019-05-18        201          201060  200202        26
# 238333 2018-08-14        219          219004  218018        25
# 238471 2019-05-19        261          261331  261111        87
# ...           ...        ...             ...     ...       ...
# 82354  2019-04-03         18           18302   15551         2
# 82357  2018-09-23         18           18420   15697        91
# 172438 2018-07-31          3            3290    2349        36
# 82358  2019-05-23         18           18420   15698        52
# 32479  2018-08-14        128          128103  131207       107
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES
# 69762           Dorito Corn Chp     Supreme 380g       200      650.0
# ...

# %% [markdown]
# Check if any incorrect entries

# %%
customerData.PROD_NAME
# Out:
# 0           Natural Chip        Compny SeaSalt175g
# 1                         CCs Nacho Cheese    175g
# 2           Smiths Crinkle Cut  Chips Chicken 170g
# 3           Smiths Chip Thinly  S/Cream&Onion 175g
# 4         Kettle Tortilla ChpsHny&Jlpno Chili 150g
#                             ...
# 264831     Kettle Sweet Chilli And Sour Cream 175g
# 264832               Tostitos Splash Of  Lime 175g
# 264833                    Doritos Mexicana    170g
# 264834     Doritos Corn Chip Mexican Jalapeno 150g
# 264835               Tostitos Splash Of  Lime 175g
# Name: PROD_NAME, Length: 264836, dtype: object

# %%
words=[]
for i in customerData.PROD_NAME :
    for s in i.split():
        words.append(s)

# %%
pd.set_option('display.max_rows', None)
w_list=pd.Series(words)
print(w_list.value_counts())
# Out:
# 175g                  60561
# Chips                 49770
# 150g                  41633
# Kettle                41288
# &                     35565
# Smiths                28860
# Salt                  27976
# Cheese                27890
# 134g                  25102
# Pringles              25102
# Doritos               24962
# Crinkle               23960
# 110g                  22387
# Corn                  22063
# Original              21560
# Cut                   20754
# Chip                  18645
# 170g                  18502
# Salsa                 18094
# Chicken               15407
# 165g                  15297
# Sea                   14145
# Thins                 14075
# Sour                  13882
# Crisps                12607
# 330g                  12540
# Vinegar               12402
# Chilli                12389
# 300g                  12041
# RRD                   11894
# Infuzions             11057
# Supreme               10963
# WW                    10320
# ...

# %% [markdown]
# Remove digits, and special characters, and then sort the distinct words by frequency of occurrence

# %%
s='Natural Chip        Compny SeaSalt175g'
s.split()
# Out:
# ['Natural', 'Chip', 'Compny', 'SeaSalt175g']
